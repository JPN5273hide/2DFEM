# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/approximates.csv', header=None)
df.iloc[::-1]
# Out:
#           0         1         2         3         4         5         6   \
# 54  1.000000  1.003086  1.006173  1.009259  1.012346  1.015432  1.018519
# 53  0.966049  0.969136  0.972222  0.975309  0.978395  0.981481  0.984568
# 52  0.932099  0.935185  0.938272  0.941358  0.944444  0.947531  0.950617
# 51  0.898148  0.901235  0.904321  0.907407  0.910494  0.913580  0.916667
# 50  0.864198  0.867284  0.870370  0.873457  0.876543  0.879630  0.882716
# 49  0.830247  0.833333  0.836420  0.839506  0.842593  0.845679  0.848765
# 48  0.796296  0.799383  0.802469  0.805556  0.808642  0.811728  0.814815
# 47  0.762346  0.765432  0.768519  0.771605  0.774691  0.777778  0.780864
# 46  0.728395  0.731481  0.734568  0.737654  0.740741  0.743827  0.746914
# 45  0.694444  0.697531  0.700617  0.703704  0.706790  0.709877  0.712963
# 44  0.666667  0.669753  0.672840  0.675926  0.679012  0.682099  0.685185
# 43  0.638889  0.641975  0.645062  0.648148  0.651235  0.654321  0.657407
# ...

# %%
sns.heatmap(df.iloc[::-1], cmap='jet')
plt.rcParams["font.size"] = 6

# %%
df_CG = pd.read_csv('data/approximates_CG.csv', header=None)
df_CG.iloc[::-1]
sns.heatmap(df_CG.iloc[::-1], cmap='jet')
plt.rcParams["font.size"] = 6
